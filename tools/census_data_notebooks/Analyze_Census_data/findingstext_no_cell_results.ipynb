# %% [markdown]
# ## This notebook analyzes ELECFINDINGSTEXT csv data

# %%
import pandas as pd

# %%
df_findingstext = pd.read_csv("/Users/sudhaukumar/Documents/Development/Census_raw_data_to_S3/raw_data_for_GFAC/DISSEMINATION-ELECFINDINGSTEXT-EXPORT.csv", low_memory=False)
df_findingstext.head()

# %%
df_findingstext["TEXT"].head()

# %%
for i in range(10):
    print("\nTEXT", i)
    print({df_findingstext["TEXT"][i]})

# %%
df_findingstext[(df_findingstext['DBKEY'] == '246080') & (df_findingstext['AUDITYEAR'] == '2016')]
