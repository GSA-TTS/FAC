# %% [markdown]
# ## This notebook analyzes ELECNOTES csv data

# %%
import pandas as pd

# %%
df_notes_to_sefa = pd.read_csv("/Users/sudhaukumar/Documents/Development/Census_raw_data_to_S3/raw_data_for_GFAC/DISSEMINATION-ELECNOTES-EXPORT.csv", low_memory=False)
df_notes_to_sefa.head()

# %%
df_notes_to_sefa.shape

# %%
df_notes_to_sefa.columns

# %%
for i in range(10):
    print("\nCONTENT", i)
    print({df_notes_to_sefa["CONTENT"][i]})

# %%
for i in range(482255, 482265):
    print("\nCONTENT", i)
    print({df_notes_to_sefa["CONTENT"][i]})

# %%
df_notes_to_sefa["CONTENT"].tail()

# %%
df_notes_to_sefa[(df_notes_to_sefa['DBKEY'] == '246080') & (df_notes_to_sefa['AUDITYEAR'] == '2016')]
