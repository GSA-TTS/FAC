# %% [markdown]
# ## This notebook is for analyzing ELECAUDITS csv data

# %% [markdown]
# ### Install libraries needed for loading into database

# %%
pip install psycopg2-binary

# %%
pip install sqlalchemy

# %%
import pandas as pd
import psycopg2
from sqlalchemy import create_engine

# %%
df_elecaudits = pd.read_csv("/Users/sudhaukumar/Documents/Development/Census_raw_data_to_S3/raw_data_for_GFAC/DISSEMINATION-ELECAUDITS-EXPORT.csv", low_memory=False)
df_elecaudits.head()

# %%
df_elecaudits.shape

# %%
df_elecaudits.columns

# %% [markdown]
# ### Use following 3 cells to load into postgres database, if needed

# %%
url = "postgresql://postgres:1234@localhost:5432/postgres"

connection = psycopg2.connect(url)
connection.autocommit = True
cursor = connection.cursor()

cursor.execute("SELECT version();")
version = cursor.fetchone()
print(version)

# %%
url = "postgresql://postgres:1234@localhost:5432/postgres"
engine = create_engine(url)
df_elecaudits.to_sql('c2g_elecaudits', con=engine, if_exists= 'append', index=False)

# %%
connection.close()

# %% [markdown]
# ### Analyze various columns in ELECADITS

# %%
df_elecaudits["AWARDIDENTIFICATION"].value_counts(dropna=False)

# %%
df_elecaudits["AUDITYEAR"].value_counts(dropna=False)

# %%
df_elecaudits["CFDA"].value_counts(dropna=False)

# %%
df_elecaudits["FEDERALPROGRAMNAME"].value_counts(dropna=False)

# %%
df_elecaudits[df_elecaudits["FEDERALPROGRAMNAME"] == 'NUESTRAS VOCES']

# %% [markdown]
# ### Check to see if numerical columns have non numerical values

# %%
df_elecaudits.ELECAUDITSID.str.extract('([^a-zA-Z\d\-])').value_counts(dropna=False)

# %%
df_elecaudits.AMOUNT.str.extract('([^a-zA-Z\d\-])').value_counts(dropna=False)

# %%
df_elecaudits.LOANBALANCE.str.extract('([^a-zA-Z\d\-])').value_counts(dropna=False)

# %%
df_elecaudits.PASSTHROUGHAMOUNT.str.extract('([^a-zA-Z\d\-])').value_counts(dropna=False)

# %%
df_elecaudits.PROGRAMTOTAL.str.extract('([^a-zA-Z\d\-])').value_counts(dropna=False)

# %%
df_elecaudits.CLUSTERTOTAL.str.extract('([^a-zA-Z\d\-])').value_counts(dropna=False)

# %%
#df_elecaudits.tail()

# %% [markdown]
# ### Check a subset

# %%
df_elecaudits_sub = df_elecaudits.iloc[11550:12000, ]

# %%
df_elecaudits_sub.to_csv("elecaudits_sub.csv")

# %%
df_elecaudits_sub.duplicated().value_counts()
