# %% [markdown]
# ## This notebook is for analyzing ELECAUDITHEADER csv data

# %%
import pandas as pd

# %%
df_elecauditheader = pd.read_csv("/Users/sudhaukumar/Documents/Development/Census_raw_data_to_S3/raw_data_for_GFAC/DISSEMINATION-ELECAUDITHEADER-EXPORT.csv")
df_elecauditheader.head()

# %%
df_elecauditheader.shape

# %%
df_elecauditheader.columns

# %% [markdown]
# ### Check columns

# %%
df_elecauditheader["ENTITY_TYPE"].value_counts(dropna=False)

# %%
df_elecauditheader["AUDITYEAR"].value_counts(dropna=False)

# %%
df_elecauditheader['AUDITTYPE'].value_counts(dropna=False)

# %%
df_elecauditheader['CITY'].value_counts(dropna=False)

# %%
df_elecauditheader['STATE'].value_counts(dropna=False)

# %%
df_elecauditheader['ZIPCODE'].value_counts(dropna=False)

# %%
df_elecauditheader['COGAGENCY'].value_counts(dropna=False)

# %%
df_elecauditheader['OVERSIGHTAGENCY'].value_counts(dropna=False)

# %% [markdown]
# ### Check to see if numerical columns have non numerical values

# %%
df_elecauditheader.ELECAUDITHEADERID.str.extract('([^a-zA-Z\d\-])').value_counts(dropna=False)

# %%
df_elecauditheader.ID.str.extract('([^a-zA-Z\d\-])').value_counts(dropna=False)

# %%
df_elecauditheader.DBKEY.str.extract('([^a-zA-Z\d\-])').value_counts(dropna=False)

# %% [markdown]
# ### Other checks

# %%
df_elecauditheader['AUDITEENAME'].tail(10)

# %%
df_elecauditheader[(df_elecauditheader['DBKEY'] == '246080') & (df_elecauditheader['AUDITYEAR'] == '2016')]

# %%
df_elecauditheader[(df_elecauditheader['DBKEY'] == '246080') & (df_elecauditheader['AUDITYEAR'] == '2016')]["ENTITY_TYPE"]

# %% [markdown]
# ### Map Census ENTITY_TYPE to GSAFAC ENTITY_TYPE

# %%
# Note: Convert Census ENTITY_TYPE to lowercase and map to GSAFAC ENTITY_TYPE

# %%
entity_type_dict = {
    "non-profit" : "Non-profit",
    "institution of higher education (ihe)" : "Institution of higher education (IHE)",
    "indian tribe or tribal organization" : "Indian Tribe or Tribal Organization",
    "local government" : "Local Government",
    "state" : "State",
    "unknown" : "Unknown",
    "nan" : "None of these (for example, for-profit)"
}

# %%
entity_type_dict["Indian tribe or Tribal organization".lower()]

# %%
entity_type_dict["INDIAN TRIBE OR TRIBAL ORGANIZATION".lower()]

# %%
entity_type_dict["Institution of higher education (IHE)".lower()]

# %%
entity_type_dict["INSTITUTION OF HIGHER EDUCATION (IHE)".lower()]

# %%
entity_type_dict["Local government".lower()]

# %%
entity_type_dict["Local Government".lower()]

# %%
entity_type_dict["LOCAL GOVERNMENT".lower()]

# %%
entity_type_dict["nan".lower()]

# %%
entity_type_dict["Non-profit".lower()]

# %%
entity_type_dict["Non-Profit".lower()]

# %%
entity_type_dict["NON-PROFIT".lower()]

# %%
entity_type_dict["State".lower()]

# %%
entity_type_dict["STATE".lower()]

# %%
entity_type_dict["Unknown".lower()]

# %%
entity_type_dict["UNKNOWN".lower()]
