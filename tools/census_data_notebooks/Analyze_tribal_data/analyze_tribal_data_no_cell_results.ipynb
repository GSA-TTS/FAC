# %%
import pandas as pd

# %%
df_elecauditheader = pd.read_csv("/Users/sudhaukumar/Documents/Development/Census_raw_data_to_S3/raw_data_for_GFAC/DISSEMINATION-ELECAUDITHEADER-EXPORT.csv")

# %%
df_elecauditheader.shape

# %%
df_no_rows_w_headers = df_elecauditheader[(df_elecauditheader != df_elecauditheader.columns).all(axis=1)]

# %%
df_no_rows_w_headers.shape

# %%
df_no_rows_w_headers["SUPPRESSION_CODE"].value_counts(dropna=False)

# %%
df_elecauditheader_tribal = df_no_rows_w_headers[df_no_rows_w_headers["SUPPRESSION_CODE"] == 'IT']

# %%
df_elecauditheader_tribal.shape

# %%
df_elecauditheader_tribal.to_csv("elecauditheader.csv")

# %%
df_elecauditheader_tribal["AUDITTYPE"].value_counts(dropna=False)

# %%
df_elecauditheader_tribal["SUPPRESSION_CODE"].value_counts(dropna=False)

# %%
df_elecaudits = pd.read_csv("/Users/sudhaukumar/Documents/Development/Census_raw_data_to_S3/raw_data_for_GFAC/DISSEMINATION-ELECAUDITS-EXPORT.csv", low_memory=False)

# %%
df_elecaudits.shape

# %%
df_elecaudits_tribal_sub = df_elecaudits[(df_elecaudits['AUDITYEAR'].isin(list(df_elecauditheader_tribal['AUDITYEAR'].astype(str)))) &
                                    (df_elecaudits['DBKEY'].isin(list(df_elecauditheader_tribal['DBKEY'].astype(str))))]

# %%
df_elecaudits_tribal_sub.shape

# %%
df_elecaudits_tribal_sub["AUDITYEAR"].value_counts(dropna=False)

# %%
df_elecaudits_tribal_sub.to_csv("elecaudits.csv")

# %%
df_elecaudits_tribal_sub[df_elecaudits_tribal_sub["CFDA"].str.len() > 6]["CFDA"]

# %%
df_elecaudits_tribal_sub[df_elecaudits_tribal_sub["CFDA"].str.len() > 7]["CFDA"]

# %%
df_elecaudits_tribal_sub["LOANBALANCE"].value_counts(dropna=False)

# %%
df_elecaudits_tribal_sub["FEDERALPROGRAMNAME"].value_counts(dropna=False)

# %%
df_elecauditfindings = pd.read_csv("/Users/sudhaukumar/Documents/Development/Census_raw_data_to_S3/raw_data_for_GFAC/DISSEMINATION-ELECAUDITFINDINGS-EXPORT.csv", low_memory=False)

# %%
df_elecauditfindings_tribal_sub = df_elecauditfindings[(df_elecauditfindings['AUDITYEAR'].isin(list(df_elecauditheader_tribal['AUDITYEAR'].astype(str)))) &
                                    (df_elecauditfindings['DBKEY'].isin(list(df_elecauditheader_tribal['DBKEY'].astype(str))))]

# %%
df_elecauditfindings_tribal_sub.shape

# %%
df_elecauditfindings_tribal_sub.to_csv("elecauditfindings.csv")

# %%
df_eleccaptext = pd.read_csv("/Users/sudhaukumar/Documents/Development/Census_raw_data_to_S3/raw_data_for_GFAC/DISSEMINATION-ELECCAPTEXT-EXPORT.csv", low_memory=False)

# %%
df_eleccaptext_tribal_sub = df_eleccaptext[(df_eleccaptext['AUDITYEAR'].isin(list(df_elecauditheader_tribal['AUDITYEAR'].astype(str)))) &
                                    (df_eleccaptext['DBKEY'].isin(list(df_elecauditheader_tribal['DBKEY'].astype(str))))]

# %%
df_eleccaptext_tribal_sub.shape

# %%
df_eleccaptext_tribal_sub.to_csv("eleccaptext.csv")

# %%
df_eleccpas = pd.read_csv("/Users/sudhaukumar/Documents/Development/Census_raw_data_to_S3/raw_data_for_GFAC/DISSEMINATION-ELECCPAS-EXPORT.csv", low_memory=False)

# %%
df_eleccpas_tribal_sub = df_eleccpas[(df_eleccpas['AUDITYEAR'].isin(list(df_elecauditheader_tribal['AUDITYEAR'].astype(str)))) &
                                    (df_eleccpas['DBKEY'].isin(list(df_elecauditheader_tribal['DBKEY'].astype(str))))]

# %%
df_eleccpas_tribal_sub.shape

# %%
df_eleccpas_tribal_sub.to_csv("eleccpas.csv")

# %%
df_eleceins = pd.read_csv("/Users/sudhaukumar/Documents/Development/Census_raw_data_to_S3/raw_data_for_GFAC/DISSEMINATION-ELECEINS-EXPORT.csv", low_memory=False)

# %%
df_eleceins_tribal_sub = df_eleceins[(df_eleceins['AUDITYEAR'].isin(list(df_elecauditheader_tribal['AUDITYEAR'].astype(str)))) &
                                    (df_eleceins['DBKEY'].isin(list(df_elecauditheader_tribal['DBKEY'].astype(str))))]

# %%
df_eleceins_tribal_sub.shape

# %%
df_eleceins_tribal_sub.to_csv("eleceins.csv")

# %%
df_elecfindingstext = pd.read_csv("/Users/sudhaukumar/Documents/Development/Census_raw_data_to_S3/raw_data_for_GFAC/DISSEMINATION-ELECFINDINGSTEXT-EXPORT.csv", low_memory=False)

# %%
df_elecfindingstext_tribal_sub = df_elecfindingstext[(df_elecfindingstext['AUDITYEAR'].isin(list(df_elecauditheader_tribal['AUDITYEAR'].astype(str)))) &
                                    (df_elecfindingstext['DBKEY'].isin(list(df_elecauditheader_tribal['DBKEY'].astype(str))))]

# %%
df_elecfindingstext_tribal_sub.shape

# %%
df_elecfindingstext_tribal_sub.to_csv("elecfindingstext.csv")

# %%
df_elecnotes = pd.read_csv("/Users/sudhaukumar/Documents/Development/Census_raw_data_to_S3/raw_data_for_GFAC/DISSEMINATION-ELECNOTES-EXPORT.csv", low_memory=False)

# %%
df_elecnotes_tribal_sub = df_elecnotes[(df_elecnotes['AUDITYEAR'].isin(list(df_elecauditheader_tribal['AUDITYEAR'].astype(str)))) &
                                    (df_elecnotes['DBKEY'].isin(list(df_elecauditheader_tribal['DBKEY'].astype(str))))]

# %%
df_elecnotes_tribal_sub.shape

# %%
df_elecnotes_tribal_sub.to_csv("elecnotes.csv")

# %%
df_elecpassthrough = pd.read_csv("/Users/sudhaukumar/Documents/Development/Census_raw_data_to_S3/raw_data_for_GFAC/DISSEMINATION-ELECPASSTHROUGH-EXPORT.csv", low_memory=False)

# %%
df_elecpassthrough_tribal_sub = df_elecpassthrough[(df_elecpassthrough['AUDITYEAR'].isin(list(df_elecauditheader_tribal['AUDITYEAR'].astype(str)))) &
                                    (df_elecpassthrough['DBKEY'].isin(list(df_elecauditheader_tribal['DBKEY'].astype(str))))]

# %%
df_elecpassthrough_tribal_sub.shape

# %%
df_elecpassthrough_tribal_sub.to_csv("elecpassthrough.csv")

# %%
df_elecueis = pd.read_csv("/Users/sudhaukumar/Documents/Development/Census_raw_data_to_S3/raw_data_for_GFAC/DISSEMINATION-ELECUEIS-EXPORT.csv", low_memory=False)

# %%
df_elecueis_tribal_sub = df_elecueis[(df_elecueis['AUDITYEAR'].isin(list(df_elecauditheader_tribal['AUDITYEAR'].astype(str)))) &
                                    (df_elecueis['DBKEY'].isin(list(df_elecauditheader_tribal['DBKEY'].astype(str))))]

# %%
df_elecueis_tribal_sub.shape

# %%
df_elecueis_tribal_sub.to_csv("elecueis.csv")
